# %%
# Install Historic-Crypto
# Documentation: https://pypi.org/project/Historic-Crypto/
# pip install Historic-Crypto

# %%
from Historic_Crypto import HistoricalData
from Historic_Crypto import Cryptocurrencies
from Historic_Crypto import LiveCryptoData

# %%
Cryptocurrencies().find_crypto_pairs()
# Out:
# Connected to the CoinBase Pro API.
# Extended Output is False, returning reduced dataset.
#             id display_name  fx_stablecoin max_slippage_percentage  status
# 0     ETH-USDC     ETH/USDC          False              0.03000000  online
# 1    MATIC-BTC    MATIC/BTC          False              0.03000000  online
# 2      CLV-GBP      CLV/GBP          False              0.03000000  online
# 3      LRC-BTC      LRC/BTC          False              0.03000000  online
# 4      FIL-GBP      FIL/GBP          False              0.03000000  online
# ..         ...          ...            ...                     ...     ...
# 373  AVAX-USDT    AVAX/USDT          False              0.03000000  online
# 374   ALCX-EUR     ALCX/EUR          False              0.03000000  online
# 375    PAX-USD      PAX/USD           True              0.01000000  online
# 376   BICO-USD     BICO/USD          False              0.03000000  online
# 377   TRU-USDT     TRU/USDT          False              0.03000000  online
#
# [378 rows x 5 columns]

# %%
data = Cryptocurrencies(coin_search = 'BTC', extended_output=False).find_crypto_pairs()
# Out:
# Connected to the CoinBase Pro API.
# Found 75 instances containing the term BTC.
# Extended Output is False, returning reduced dataset.

# %%
new = HistoricalData('BTC-USD',300,'2021-11-01-00-00', '2021-11-30-00-00').retrieve_data()
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2021-11-01T00:00:00
# Provisional End: 2021-11-02T01:00:00
# Data for chunk 1 of 28 extracted
# Provisional Start: 2021-11-02T01:00:00
# Provisional End: 2021-11-03T02:00:00
# Data for chunk 2 of 28 extracted
# Provisional Start: 2021-11-03T02:00:00
# Provisional End: 2021-11-04T03:00:00
# Data for chunk 3 of 28 extracted
# Provisional Start: 2021-11-04T03:00:00
# Provisional End: 2021-11-05T04:00:00
# Data for chunk 4 of 28 extracted
# Provisional Start: 2021-11-05T04:00:00
# Provisional End: 2021-11-06T05:00:00
# Data for chunk 5 of 28 extracted
# Provisional Start: 2021-11-06T05:00:00
# Provisional End: 2021-11-07T06:00:00
# Data for chunk 6 of 28 extracted
# Provisional Start: 2021-11-07T06:00:00
# Provisional End: 2021-11-08T07:00:00
# Data for chunk 7 of 28 extracted
# Provisional Start: 2021-11-08T07:00:00
# Provisional End: 2021-11-09T08:00:00
# Data for chunk 8 of 28 extracted
# Provisional Start: 2021-11-09T08:00:00
# Provisional End: 2021-11-10T09:00:00
# Data for chunk 9 of 28 extracted
# Provisional Start: 2021-11-10T09:00:00
# Provisional End: 2021-11-11T10:00:00
# Data for chunk 10 of 28 extracted
# Provisional Start: 2021-11-11T10:00:00
# Provisional End: 2021-11-12T11:00:00
# Data for chunk 11 of 28 extracted
# Provisional Start: 2021-11-12T11:00:00
# Provisional End: 2021-11-13T12:00:00
# Data for chunk 12 of 28 extracted
# Provisional Start: 2021-11-13T12:00:00
# Provisional End: 2021-11-14T13:00:00
# Data for chunk 13 of 28 extracted
# Provisional Start: 2021-11-14T13:00:00
# Provisional End: 2021-11-15T14:00:00
# Data for chunk 14 of 28 extracted
# Provisional Start: 2021-11-15T14:00:00
# Provisional End: 2021-11-16T15:00:00
# Data for chunk 15 of 28 extracted
# Provisional Start: 2021-11-16T15:00:00
# Provisional End: 2021-11-17T16:00:00
# Data for chunk 16 of 28 extracted
# Provisional Start: 2021-11-17T16:00:00
# Provisional End: 2021-11-18T17:00:00
# Data for chunk 17 of 28 extracted
# Provisional Start: 2021-11-18T17:00:00
# Provisional End: 2021-11-19T18:00:00
# Data for chunk 18 of 28 extracted
# Provisional Start: 2021-11-19T18:00:00
# Provisional End: 2021-11-20T19:00:00
# Data for chunk 19 of 28 extracted
# Provisional Start: 2021-11-20T19:00:00
# Provisional End: 2021-11-21T20:00:00
# Data for chunk 20 of 28 extracted
# Provisional Start: 2021-11-21T20:00:00
# Provisional End: 2021-11-22T21:00:00
# Data for chunk 21 of 28 extracted
# Provisional Start: 2021-11-22T21:00:00
# Provisional End: 2021-11-23T22:00:00
# Data for chunk 22 of 28 extracted
# Provisional Start: 2021-11-23T22:00:00
# Provisional End: 2021-11-24T23:00:00
# Data for chunk 23 of 28 extracted
# Provisional Start: 2021-11-24T23:00:00
# Provisional End: 2021-11-26T00:00:00
# Data for chunk 24 of 28 extracted
# Provisional Start: 2021-11-26T00:00:00
# Provisional End: 2021-11-27T01:00:00
# Data for chunk 25 of 28 extracted
# Provisional Start: 2021-11-27T01:00:00
# Provisional End: 2021-11-28T02:00:00
# Data for chunk 26 of 28 extracted
# Provisional Start: 2021-11-28T02:00:00
# Provisional End: 2021-11-29T03:00:00
# Data for chunk 27 of 28 extracted
# Provisional Start: 2021-11-29T03:00:00
# Provisional End: 2021-11-30T04:00:00
# Data for chunk 28 of 28 extracted

# %%
print(new)
# Out:
#                           low      high      open     close     volume
# time
# 2021-11-01 00:05:00  61284.60  61440.57  61294.74  61430.34  59.848231
# 2021-11-01 00:10:00  61405.63  61599.88  61438.70  61562.69  42.051565
# 2021-11-01 00:15:00  61520.57  61700.86  61563.64  61696.83  33.609489
# 2021-11-01 00:20:00  61513.18  61709.82  61696.84  61526.40  33.383990
# 2021-11-01 00:25:00  61515.65  61643.29  61517.98  61551.79  24.178809
# ...                       ...       ...       ...       ...        ...
# 2021-11-29 23:40:00  57830.01  57997.26  57990.43  57869.59  39.985875
# 2021-11-29 23:45:00  57730.90  57961.16  57871.14  57793.03  42.363818
# 2021-11-29 23:50:00  57775.00  57950.76  57799.54  57875.25  60.442608
# 2021-11-29 23:55:00  57800.94  57896.92  57875.25  57838.06  28.045249
# 2021-11-30 00:00:00  57625.01  57863.92  57838.06  57667.76  61.634655
#
# [8342 rows x 5 columns]

# %%
# Converting to CSV File

bitcoinCSV = new.to_csv('BitcoinData_CSV_V1.csv')

# %%
# Converting to JSON File

bitcoinJson = new.to_json('BitcoinData_JSON_V1.json')
